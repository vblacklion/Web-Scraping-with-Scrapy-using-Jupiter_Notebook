# %%
# importing necessery modules
import pandas as pd
import numpy as np
import json
import re

# %%
# to see all of the columns
from IPython.display import display
pd.options.display.max_columns=None

# %%
data = []
with open('scout_mmwd.json') as f:
    for line in f:
        data.append(json.loads(line))

# %%
df = pd.DataFrame(data)
df.head(3)
# Out:
#                            \nComfort & Convenience\n  \
# 0  [Air conditioning, Armrest, Automatic climate ...
# 1  [Air conditioning, Automatic climate control, ...
# 2  [Air conditioning, Armrest, Automatic climate ...
#
#                            \nEntertainment & Media\n  \
# 0  [Bluetooth, CD player, Digital radio, Hands-fr...
# 1                             [Hands-free equipment]
# 2  [Bluetooth, CD player, Digital radio, Hands-fr...
#
#                                           \nExtras\n  \
# 0  [Alloy wheels, Roof rack, Shift paddles, Sport...
# 1                                        [Roof rack]
# 2  [Alloy wheels, Roof rack, Shift paddles, Sport...
#
#                                \nSafety & Security\n  \
# 0  [ABS, Adaptive Cruise Control, Blind spot moni...
# 1                                   [LED Headlights]
# 2  [ABS, Adaptive Cruise Control, Adaptive headli...
#
#                     Availability Available from                Body  \
# ...
