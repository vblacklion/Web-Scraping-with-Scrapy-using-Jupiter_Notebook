# %%
# Importing scrapy
import scrapy
from scrapy.crawler import CrawlerProcess
# Defining the spider class
# MMWD: Multiple Models With Details

# import items from items.py

#from autocrawler.items import AutocrawlerItem

class ScoutAutoCrawler(scrapy.Spider):
    
    name = "scout_mmwd"
    
    allowed_domains = ["autoscout24.com"]
    
    def start_requests( self ):         
        #page_number = 1
        base_url = "https://www.autoscout24.com/"
        makes = ['ateca', 'other',]
        #models = {"audi" : ['a4', 'a6', 'a5'],
        #          "opel" : ['corsa', 'adam', 'meriva'],
        #          "renault" : ['clio', 'duster', 'scenic']
        #          }
        #years = ["2014", "2015"]
        #desc = ["0", "1"]
        #gear = ["A", "M", "S"]
        
        
        #for i in range(3):
        #    l = len(models[makes[i]])
        #    for x in range(l):
        #        for y in range(2):
        #            for a in range(2):
        #                for g in range(3):
        #                    for page_number in range(1,21):
        #                
        #                        url = base_url+"lst/"+makes[i]+"/"+models[makes[i]][x]+"?sort=price&\
        #                        desc="+desc[a]+"&gear="+gear[g]+"&ustate=N%2CU&size=20&page="+str(page_number)+"&\
        #                        fregto="+years[y]+"&fregfrom="+years[y]+"&atype=C&"
        
        for i in range(2):
            for page_number in range(1,21):
                url = base_url + "lst/cupra/" + makes[i] + "?sort=price&desc=0&ustate=N%2CU&size=20&page=" + str(page_number) + "1&atype=C&"
        
                yield scrapy.Request( url = url, callback = self.parse) 
    

    def parse(self, response):
        
        base_url = "https://www.autoscout24.com/"
        all_auto_divs = response.css(".cldt-summary-full-item-main")
        
        for auto_divs in all_auto_divs:
            
            #advertisement details link finder
            detail_page = auto_divs.css(".cldt-summary-titles")
            link = detail_page.css('a::attr(href)').extract_first()          
        
            yield scrapy.Request( url = base_url+link, callback = self.parse_details)
        
    
    def parse_details(self, response):
        
        items = {}
        
        headline = response.css(".cldt-headline")
        make_model = headline.css("h1.cldt-detail-title > span:nth-child(1) ::text").extract_first()
        short_description = headline.css("h1.cldt-detail-title > span:nth-child(2) ::text").extract_first()
        body_type = headline.css("h4.cldt-detail-subheadline ::text").extract_first()
        
        stage = response.css(".cldt-stage-data")
        price = stage.css("div.cldt-price > h2 ::text").extract_first()
        vat = stage.css("div.cldt-stage-headline > div:nth-child(2) > p > span ::text").extract_first()
        km = stage.css("div.cldt-stage-basic-data > div:nth-child(1) > span ::text").extract_first()
        registration = stage.css("div.cldt-stage-basic-data > div:nth-child(2) > span:nth-child(1)::text").extract_first()
        prev_owner = stage.css("div.cldt-stage-basic-data > div:nth-child(2) > span:nth-child(2)::text").extract_first()
        kW = stage.css("div.cldt-stage-basic-data > div:nth-child(3) > span:nth-child(1)::text").extract_first()
        hp = stage.css("div.cldt-stage-basic-data > div:nth-child(3) > span:nth-child(2)::text").extract_first()
        
        items["url"] = response.url
        
        Details = response.css("div.cldt-item[data-item-name='car-details']")
        details = Details.css("div.sc-grid-row > div:nth-child(1)")
        #details
        state_1 = details.css("div:nth-child(1) > dl > dt:nth-child(1) ::text").extract_first()
        state_2 = details.css("div:nth-child(1) > dl > dd:nth-child(2) ::text").extract()
        
        state_3 = details.css("div:nth-child(1) > dl > dt:nth-child(3) ::text").extract_first()
        state_4 = details.css("div:nth-child(1) > dl > dd:nth-child(4) ::text").extract_first()
        
        state_5 = details.css("div:nth-child(1) > dl > dt:nth-child(5) ::text").extract_first()
        state_6 = details.css("div:nth-child(1) > dl > dd:nth-child(6) ::text").extract()
        
        state_7 = details.css("div:nth-child(1) > dl > dt:nth-child(7) ::text").extract_first()
        state_8 = details.css("div:nth-child(1) > dl > dd:nth-child(8) ::text").extract()
        
        state_9 = details.css("div:nth-child(1) > dl > dt:nth-child(9) ::text").extract_first()
        state_10 = details.css("div:nth-child(1) > dl > dd:nth-child(10) ::text").extract()
        
        state_11 = details.css("div:nth-child(1) > dl > dt:nth-child(11) ::text").extract_first()
        state_12 = details.css("div:nth-child(1) > dl > dd:nth-child(12) ::text").extract()
        
        state_13 = details.css("div:nth-child(1) > dl > dt:nth-child(13) ::text").extract_first()
        state_14 = details.css("div:nth-child(1) > dl > dd:nth-child(14) ::text").extract()
        
        state_15 = details.css("div:nth-child(1) > dl > dt:nth-child(15) ::text").extract_first()
        state_16 = details.css("div:nth-child(1) > dl > dd:nth-child(16) ::text").extract()
        
        state_17 = details.css("div:nth-child(1) > dl > dt:nth-child(17) ::text").extract_first()
        state_18 = details.css("div:nth-child(1) > dl > dd:nth-child(18) ::text").extract()
        
        state_19 = details.css("div:nth-child(1) > dl > dt:nth-child(19) ::text").extract_first()
        state_20 = details.css("div:nth-child(1) > dl > dd:nth-child(20) ::text").extract()
        
        #properties
        properties_1 = details.css("div:nth-child(2) > dl > dt:nth-child(1) ::text").extract_first()
        properties_2 = details.css("div:nth-child(2) > dl > dd:nth-child(2) ::text").extract_first()
        
        properties_3 = details.css("div:nth-child(2) > dl > dt:nth-child(3) ::text").extract_first()        
        properties_4 = details.css("div:nth-child(2) > dl > dd:nth-child(4) ::text").extract_first()

        properties_5 = details.css("div:nth-child(2) > dl > dt:nth-child(5) ::text").extract_first()        
        properties_6 = details.css("div:nth-child(2) > dl > dd:nth-child(6) ::text").extract()

        properties_7 = details.css("div:nth-child(2) > dl > dt:nth-child(7) ::text").extract_first()        
        properties_8 = details.css("div:nth-child(2) > dl > dd:nth-child(8) ::text").extract()

        properties_9 = details.css("div:nth-child(2) > dl > dt:nth-child(9) ::text").extract_first()        
        properties_10 = details.css("div:nth-child(2) > dl > dd:nth-child(10) ::text").extract()

        properties_11 = details.css("div:nth-child(2) > dl > dt:nth-child(11) ::text").extract_first()
        properties_12 = details.css("div:nth-child(2) > dl > dd:nth-child(12) ::text").extract()
        
        properties_13 = details.css("div:nth-child(2) > dl > dt:nth-child(13) ::text").extract_first()        
        properties_14 = details.css("div:nth-child(2) > dl > dd:nth-child(14) ::text").extract()

        properties_15 = details.css("div:nth-child(2) > dl > dt:nth-child(15) ::text").extract_first()        
        properties_16 = details.css("div:nth-child(2) > dl > dd:nth-child(16) ::text").extract()

        properties_17 = details.css("div:nth-child(2) > dl > dt:nth-child(17) ::text").extract_first()        
        properties_18 = details.css("div:nth-child(2) > dl > dd:nth-child(18) ::text").extract()

        properties_19 = details.css("div:nth-child(2) > dl > dt:nth-child(19) ::text").extract_first()        
        properties_20 = details.css("div:nth-child(2) > dl > dd:nth-child(20) ::text").extract()

        properties_21 = details.css("div:nth-child(2) > dl > dt:nth-child(21) ::text").extract_first()
        properties_22 = details.css("div:nth-child(2) > dl > dd:nth-child(22) ::text").extract()
        
        properties_23 = details.css("div:nth-child(2) > dl > dt:nth-child(23) ::text").extract_first()        
        properties_24 = details.css("div:nth-child(2) > dl > dd:nth-child(24) ::text").extract()

        properties_25 = details.css("div:nth-child(2) > dl > dt:nth-child(25) ::text").extract_first()        
        properties_26 = details.css("div:nth-child(2) > dl > dd:nth-child(26) ::text").extract()

        properties_27 = details.css("div:nth-child(2) > dl > dt:nth-child(27) ::text").extract_first()        
        properties_28 = details.css("div:nth-child(2) > dl > dd:nth-child(28) ::text").extract()

        properties_29 = details.css("div:nth-child(2) > dl > dt:nth-child(29) ::text").extract_first()        
        properties_30 = details.css("div:nth-child(2) > dl > dd:nth-child(30) ::text").extract()

        #drive
        drive_1 = details.css("div:nth-child(3) > dl > dt:nth-child(1) ::text").extract_first()        
        drive_2 = details.css("div:nth-child(3) > dl > dd:nth-child(2) ::text").extract()

        drive_3 = details.css("div:nth-child(3) > dl > dt:nth-child(3) ::text").extract_first()        
        drive_4 = details.css("div:nth-child(3) > dl > dd:nth-child(4) ::text").extract()

        drive_5 = details.css("div:nth-child(3) > dl > dt:nth-child(5) ::text").extract_first()        
        drive_6 = details.css("div:nth-child(3) > dl > dd:nth-child(6) ::text").extract()

        drive_7 = details.css("div:nth-child(3) > dl > dt:nth-child(7) ::text").extract_first()        
        drive_8 = details.css("div:nth-child(3) > dl > dd:nth-child(8) ::text").extract()

        drive_9 = details.css("div:nth-child(3) > dl > dt:nth-child(9) ::text").extract_first()        
        drive_10 = details.css("div:nth-child(3) > dl > dd:nth-child(10) ::text").extract()

        drive_11 = details.css("div:nth-child(3) > dl > dt:nth-child(11) ::text").extract_first()        
        drive_12 = details.css("div:nth-child(3) > dl > dd:nth-child(12) ::text").extract()

        drive_13 = details.css("div:nth-child(3) > dl > dt:nth-child(13) ::text").extract_first()        
        drive_14 = details.css("div:nth-child(3) > dl > dd:nth-child(14) ::text").extract()

        drive_15 = details.css("div:nth-child(3) > dl > dt:nth-child(15) ::text").extract_first()        
        drive_16 = details.css("div:nth-child(3) > dl > dd:nth-child(16) ::text").extract()

        drive_17 = details.css("div:nth-child(3) > dl > dt:nth-child(17) ::text").extract_first()        
        drive_18 = details.css("div:nth-child(3) > dl > dd:nth-child(18) ::text").extract()

        drive_19 = details.css("div:nth-child(3) > dl > dt:nth-child(19) ::text").extract_first()        
        drive_20 = details.css("div:nth-child(3) > dl > dd:nth-child(20) ::text").extract()

        #environment
        environment = Details.css("div.sc-grid-row > div:nth-child(2) > div > div > div")
        
        environment_1 = environment.css("div:nth-child(1) > dl > dt:nth-child(1) ::text").extract_first()
        environment_2 = environment.css("div:nth-child(1) > dl > dd:nth-child(2) ::text").extract()
        
        environment_3 = environment.css("div:nth-child(1) > dl > dt:nth-child(3) ::text").extract_first()
        environment_4a = environment.css("div:nth-child(1) > dl > dd:nth-child(4) > div:nth-child(1) ::text").extract()
        environment_4b = environment.css("div:nth-child(1) > dl > dd:nth-child(4) > div:nth-child(2) ::text").extract()
        environment_4c = environment.css("div:nth-child(1) > dl > dd:nth-child(4) > div:nth-child(3) ::text").extract()
  
        environment_5 = environment.css("div:nth-child(1) > dl > dt:nth-child(5) ::text").extract_first()
        environment_6 = environment.css("div:nth-child(1) > dl > dd:nth-child(6) ::text").extract()
        
        environment_7 = environment.css("div:nth-child(1) > dl > dt:nth-child(7) ::text").extract_first()
        environment_8 = environment.css("div:nth-child(1) > dl > dd:nth-child(8) ::text").extract()
        

        #Equipment
        Equipment = response.css("div.cldt-item[data-item-name='equipments']")
        equipment_1 = Equipment.css("div.sc-grid-row > div:nth-child(1) > h3::text").extract_first()
        equipment_2 = Equipment.css("div.sc-grid-row > div:nth-child(1) span::text").extract()
        
        equipment_3 = Equipment.css("div.sc-grid-row > div:nth-child(2) > h3::text").extract_first()
        equipment_4 = Equipment.css("div.sc-grid-row > div:nth-child(2) span::text").extract()        
        
        equipment_5 = Equipment.css("div.sc-grid-row > div:nth-child(3) > h3::text").extract_first()
        equipment_6 = Equipment.css("div.sc-grid-row > div:nth-child(3) span::text").extract()        
        
        equipment_7 = Equipment.css("div.sc-grid-row > div:nth-child(4) > h3::text").extract_first()
        equipment_8 = Equipment.css("div.sc-grid-row > div:nth-child(4) span::text").extract()        
        
        #Description
        Description = response.css("div.cldt-item[data-item-name='description']")
        description = Description.css("div.sc-grid-row > div:nth-child(1) > div:nth-child(1) ::text").extract()
        
        # saving to dictionary
        
        items["make_model"] = make_model
        items["short_description"] = short_description
        items["body_type"] = body_type
        items["price"] = int(''.join(filter(str.isdigit, price)))
        items["vat"] = vat
        items["km"] = km
        items["registration"] = registration
        items["prev_owner"] = prev_owner
        items["kW"] = kW
        items["hp"] = hp
          
        items[state_1] = "".join(state_2).splitlines()
        items[state_3] = state_4
        items[state_5] = state_6
        items[state_7] = state_8
        items[state_9] = state_10
        items[state_11] = state_12
        items[state_13] = state_14
        items[state_15] = state_16
        items[state_17] = state_18
        items[state_19] = state_20
        
        items[properties_1] = properties_2
        items[properties_3] = properties_4
        items[properties_5] = properties_6
        items[properties_7] = properties_8
        items[properties_9] = properties_10
        items[properties_11] = properties_12
        items[properties_13] = properties_14
        items[properties_15] = properties_16
        items[properties_17] = properties_18
        items[properties_19] = properties_20
        items[properties_21] = properties_22
        items[properties_23] = properties_24
        items[properties_25] = properties_26
        items[properties_27] = properties_28
        items[properties_29] = properties_30
        
        items[drive_1] = drive_2
        items[drive_3] = drive_4
        items[drive_5] = drive_6
        items[drive_7] = drive_8
        items[drive_9] = drive_10
        items[drive_11] = drive_12
        items[drive_13] = drive_14
        items[drive_15] = drive_16
        items[drive_17] = drive_18
        items[drive_19] = drive_20
        
        items[environment_1] = environment_2
        items[environment_3] = [environment_4a, environment_4b, environment_4c]
        items[environment_5] = environment_6
        items[environment_7] = environment_8
        
        items[equipment_1] = equipment_2
        items[equipment_3] = equipment_4
        items[equipment_5] = equipment_6
        items[equipment_7] = equipment_8
        
        items["description"] = description
        
        yield items

#! scrapy crawl scout_mmwd            
process = CrawlerProcess({'FEED_URI': 'scout_mmwd.json',}) 
# 
process.crawl(ScoutAutoCrawler) 
# 
process.start()
# Out:
# 2019-06-21 09:18:14 [scrapy.utils.log] INFO: Scrapy 1.6.0 started (bot: scrapybot)
# 2019-06-21 09:18:14 [scrapy.utils.log] INFO: Versions: lxml 4.3.2.0, libxml2 2.9.9, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 19.2.0, Python 3.7.3 (default, Mar 27 2019, 17:13:21) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1b  26 Feb 2019), cryptography 2.6.1, Platform Windows-10-10.0.17134-SP0
# 2019-06-21 09:18:14 [scrapy.crawler] INFO: Overridden settings: {'FEED_URI': 'scout_mmwd.json'}
# 2019-06-21 09:18:14 [scrapy.extensions.telnet] INFO: Telnet Password: ddd6e7cec8e2e698
# 2019-06-21 09:18:14 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2019-06-21 09:18:14 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2019-06-21 09:18:14 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2019-06-21 09:18:14 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2019-06-21 09:18:14 [scrapy.core.engine] INFO: Spider opened
# 2019-06-21 09:18:14 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2019-06-21 09:18:14 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=51&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=71&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=81&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=21&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=51&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=41&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=31&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=71&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=61&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=81&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=21&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=41&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=31&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=61&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=91&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=101&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=111&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=91&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=141&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=101&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=121&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=151&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=111&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=131&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=161&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=181&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=141&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=121&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=151&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=171&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=191&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=21&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=131&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=161&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=181&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=31&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=41&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.core.engine] DEBUG: Crawled (301) <GET https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=201&atype=C&> (referer: None)
# 2019-06-21 09:18:15 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=171&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:16 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:16 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=191&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:16 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=21&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-2-0tsi-4drive-gasoline-white-8e41a2ec-9e1c-45d7-b6bf-a0a35ec1e2d5> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=31&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:16 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=41&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:16 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <301 https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=201&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-dsg-4-drive-gasoline-grey-0981f235-41dc-4ca5-8a23-e9de1fa40ec2> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-4-drive-dsg-ahk-fracht-gasoline-blue-6745fceb-1b82-4105-9118-a9a4bdc52a91> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-4drive-dsg-gasoline-white-458c1647-1615-4c39-9b6c-9a502755a974> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-221kw-4drive-dsg-gasoline-white-faadb833-9a97-4b34-b629-e54d479c59bc> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-seat-ateca-2-0-tsi-4drive-dsg-navi-pano-brembo-le-gasoline-black-3d46f8ce-698f-4994-b4ea-62327481c778> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-4drive-dsg-gasoline-grey-dcb4d905-d86a-4e79-847a-ad85bc46d064> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com//offers/cupra-ateca-2-0tsi-4drive-gasoline-white-8e41a2ec-9e1c-45d7-b6bf-a0a35ec1e2d5>
# {'url': 'https://www.autoscout24.com//offers/cupra-ateca-2-0tsi-4drive-gasoline-white-8e41a2ec-9e1c-45d7-b6bf-a0a35ec1e2d5', 'make_model': 'Cupra Ateca', 'short_description': '2.0TSI 4Drive', 'body_type': 'Off-Road', 'price': 48190, 'vat': 'VAT deductible', 'km': '10 km', 'registration': None, 'prev_owner': '-/-', 'kW': None, 'hp': '221 kW', 'Type': ['', 'New', '', 'Super Plus 98'], 'Previous Owners': '\n0\n', 'Warranty': ['\n36 months\n', '\n168 g CO2/km (comb)\n'], 'Emission Class': ['\nEuro 6d\n'], 'Emission Label': ['\n4 (Green)\n'], None: [], 'Make': ['\nCupra\n'], 'Model': ['\n', 'Ateca', '\n'], 'Offer Number': ['\n529393\n'], 'Body Color': ['\n', 'White', '\n'], 'Paint Type': ['\nMetallic\n'], 'Body Color Original': ['\n"Nevada" Weiss\n'], 'Upholstery': ['\nalcantara, Black\n'], 'Body': ['\n', 'Off-Road', '\n'], 'Nr. of Doors': ['\n5\n'], 'Nr. of Seats': ['\n5\n'], 'Country version': ['\nGermany\n'], 'Gearing Type': ['\n', 'Automatic', '\n'], 'Gears': ['\n7\n'], 'Displacement': ['\n1,984 cc\n'], 'Cylinders': ['\n4\n'], 'Weight': ['\n1,615 kg\n'], 'Drive chain': ['\nfront\n'], 'Fuel': ['\n', 'Super Plus 98', '\n'], 'Consumption': [['4.7 l/100 km (comb)'], ['8.9 l/100 km (city)'], ['6.5 l/100 km (country)']], 'CO2 Emission': ['\n168 g CO2/km (comb)\n'], '\nComfort & Convenience\n': ['Air conditioning', 'Armrest', 'Automatic climate control', 'Cruise control', 'Electrical side mirrors', 'Hill Holder', 'Keyless central door lock', 'Leather steering wheel', 'Light sensor', 'Lumbar support', 'Multi-function steering wheel', 'Navigation system', 'Park Distance Control', 'Parking assist system camera', 'Parking assist system self-steering', 'Parking assist system sensors front', 'Parking assist system sensors rear', 'Power windows', 'Seat heating', 'Split rear seats', 'Start-stop system'], '\nEntertainment & Media\n': ['Bluetooth', 'CD player', 'Digital radio', 'Hands-free equipment', 'On-board computer', 'Radio', 'Sound system'], '\nExtras\n': ['Alloy wheels', 'Roof rack', 'Shift paddles', 'Sport seats', 'Trailer hitch'], '\nSafety & Security\n': ['ABS', 'Adaptive Cruise Control', 'Blind spot monitor', 'Central door lock', 'Central door lock with remote control', 'Daytime running lights', 'Driver drowsiness detection', 'Driver-side airbag', 'Electronic stability control', 'Head airbag', 'Immobilizer', 'Isofix', 'Lane departure warning system', 'LED Daytime Running Lights', 'LED Headlights', 'Passenger-side airbag', 'Power steering', 'Side airbag', 'Tire pressure monitoring system', 'Traffic sign recognition'], 'description': ['\n', 'Sonderausstattung:', 'Anhängerkupplung (Kugelkopf schwenkbar)', 'Bremsanlage: Brembo', 'Business-Paket Cupra', 'Interieur-Paket Black', 'LM-Felgen 8x19 (Cupra Diamond)', 'Virtual Cockpit', 'Reserverad als Notrad', 'Schiebe-/Hebedach elektrisch (Glas)', 'Winter-Paket', ' Full Link ', 'Fahrassistenz-Paket V ', 'Heckklappe elektrisch betätigt inkl. sensorgesteuerter Öffnung und Schließung und Kessy ', 'BREMBO 4-Kolben-High-Performance-Bremsanlage vorn ', 'Garantieverlängerung um 3 Jahre, oder maximal 100.000 km ', 'u.v.m.', 'Sie erreichen uns unter 030/ 498 998 -60 oder -24', 'Irrtümer vorbehalten', '\n']}
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-seat-cupra-ateca-2-0-tsi-4drive-dsg-gasoline-grey-10be11ab-73d1-4d2e-bb50-87daa743ba19> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-cupra-2-0tsi-dsg-4drive-pano-v-cockpit-dcc-sitzhzg-gasoline-black-2d29a523-a31c-4ca3-8689-d18b45137c3a> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-dsg-4-drive-gasoline-grey-0981f235-41dc-4ca5-8a23-e9de1fa40ec2>
# {'url': 'https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-dsg-4-drive-gasoline-grey-0981f235-41dc-4ca5-8a23-e9de1fa40ec2', 'make_model': 'Cupra Ateca', 'short_description': '2,0 TSI DSG 4 Drive', 'body_type': 'Off-Road', 'price': 47990, 'vat': None, 'km': '9,000 km', 'registration': None, 'prev_owner': '05/2019', 'kW': None, 'hp': '221 kW', 'Type': ['', 'Demonstration', '', 'Gasoline'], 'Previous Owners': '\n1\n', None: [], 'Make': ['\nCupra\n'], 'Model': ['\n', 'Ateca', '\n'], 'Offer Number': ['\n926\n'], 'First Registration': ['\n', '2019', '\n'], 'Body Color': ['\n', 'Grey', '\n'], 'Paint Type': ['\nMetallic\n'], 'Body': ['\n', 'Off-Road', '\n'], 'Nr. of Doors': ['\n5\n'], 'Nr. of Seats': ['\n5\n'], 'Country version': ['\nAustria\n'], 'Gearing Type': ['\n', 'Automatic', '\n'], 'Displacement': ['\n1,984 cc\n'], 'Drive chain': ['\n4WD\n'], 'Fuel': ['\n', 'Gasoline', '\n'], '\nComfort & Convenience\n': ['Air conditioning', 'Automatic climate control', 'Light sensor', 'Park Distance Control', 'Parking assist system sensors front', 'Parking assist system sensors rear', 'Power windows'], '\nEntertainment & Media\n': ['Hands-free equipment'], '\nExtras\n': ['Roof rack'], '\nSafety & Security\n': ['LED Headlights'], 'description': ['\nIhr Verkaufsberater:', 'Hr. Lind: 0664/263 93 39', 'Dieses Fahrzeug steht in der Filiale in Hartberg!', '8230 Hartberg, Ressavarstraße 4a, 03332/62496-30', '- Anhängevorrichtung schwenkbar', '- LED-Rückleuchten', '- Sportpaket', '- Abstandsregelung', '- Park Lenkassistent', '- Seitenfenster ab B-Säule abgedunkelt', '- Panorama Glasdach', '- Sitzheizung vorne', '- Scheinwerfer-Reinigungsanlage', '- Ausstelldach', '\n']}
# 2019-06-21 09:18:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-4-drive-dsg-ahk-fracht-gasoline-blue-6745fceb-1b82-4105-9118-a9a4bdc52a91>
# {'url': 'https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-4-drive-dsg-ahk-fracht-gasoline-blue-6745fceb-1b82-4105-9118-a9a4bdc52a91', 'make_model': 'Cupra Ateca', 'short_description': '2.0 TSI 4 Drive DSG | AHK *Fracht', 'body_type': 'Off-Road', 'price': 47990, 'vat': 'VAT deductible', 'km': '- km', 'registration': None, 'prev_owner': '-/-', 'kW': None, 'hp': '221 kW', 'Type': ['', 'New', '', 'Super Plus 98'], 'Availability': '\nin 180 days from ordering\n', 'Warranty': ['\n', '\n', '\n168 g CO2/km (comb)\n'], 'Full Service': ['\n', '\n', '\nEuro 6d-TEMP\n'], 'Non-smoking Vehicle': ['\n', '\n', '\n4 (Green)\n'], None: [], 'Make': ['\nCupra\n'], 'Model': ['\n', 'Ateca', '\n'], 'Offer Number': ['\nbes_312326\n'], 'Body Color': ['\n', 'Blue', '\n'], 'Body Color Original': ['\nEnergy Blau (K4K4)\n'], 'Upholstery': ['\nalcantara, Black\n'], 'Body': ['\n', 'Off-Road', '\n'], 'Nr. of Doors': ['\n4\n'], 'Country version': ['\nGermany\n'], 'Gearing Type': ['\n', 'Automatic', '\n'], 'Displacement': ['\n1,984 cc\n'], 'Drive chain': ['\n4WD\n'], 'Fuel': ['\n', 'Super Plus 98', '\n'], 'Consumption': [['7.4 l/100 km (comb)'], ['8.9 l/100 km (city)'], ['6.5 l/100 km (country)']], 'CO2 Emission': ['\n168 g CO2/km (comb)\n'], 'Emission Class': ['\nEuro 6d-TEMP\n'], '\nComfort & Convenience\n': ['Air conditioning', 'Armrest', 'Automatic climate control', 'Electrically adjustable seats', 'Electrically heated windshield', 'Electrical side mirrors', 'Electric tailgate', 'Hill Holder', 'Keyless central door lock', 'Leather steering wheel', 'Light sensor', 'Lumbar support', 'Multi-function steering wheel', 'Navigation system', 'Panorama roof', 'Park Distance Control', 'Parking assist system camera', 'Parking assist system self-steering', 'Parking assist system sensors front', 'Parking assist system sensors rear', 'Power windows', 'Rain sensor', 'Seat heating', 'Start-stop system', 'Sunroof'], '\nEntertainment & Media\n': ['Bluetooth', 'CD player', 'Digital radio', 'Hands-free equipment', 'On-board computer', 'Radio', 'Sound system', 'USB'], '\nExtras\n': ['Alloy wheels', 'Roof rack', 'Shift paddles', 'Sport package', 'Sport seats', 'Sport suspension', 'Touch screen', 'Trailer hitch', 'Voice Control'], '\nSafety & Security\n': ['ABS', 'Adaptive Cruise Control', 'Adaptive headlights', 'Alarm system', 'Blind spot monitor', 'Central door lock', 'Daytime running lights', 'Driver drowsiness detection', 'Driver-side airbag', 'Electronic stability control', 'Emergency brake assistant', 'Fog lights', 'Immobilizer', 'Isofix', 'Lane departure warning system', 'LED Daytime Running Lights', 'LED Headlights', 'Passenger-side airbag', 'Power steering', 'Side airbag', 'Tire pressure monitoring system', 'Traction control', 'Traffic sign recognition'], 'description': ['\n', 'SEAT Ateca\xa0Cupra 2.0 TSI 4 Drive DSG |\xa0BREMBO | Beats |*inkl. Frachtkosten ab Werk', '*SALE auf Frontbild: Nachlass, bzw. Preisvorteil in % gegenüber der unverbindlichen Preisempfehlung des Herstellers. ', 'Bei Sondermodellen zusätzlich inklusive Sondermodell-Preisvorteil des Herstellers für ein vergleichbar ausgestattetes Modell.\xa0', 'Gebe bitte die ', 'Fahrzeugnummer bes_243230 auf www.autos-erleben.de im Suchfeld', ' ', 'ein', ', hier findest Du noch mehr relevante Infos.\xa0', 'Außenfarbe:', '\xa0blau(Energy Blau (K4K4))\xa0| ', 'Innenfarbe:', ' schwarz', 'Highlights:', 'Voll-LED-Scheinwerfer', 'Panorama Glas Schiebedach', 'Navigationssystem Plus', 'Full Link\xa0und Top View Rückfahrkamera', 'Fahrersitz elektrisch einstellbar', 'Schlüsselloses Schließ & Startsystem Kessy', 'Automatische Distanzregelung ACC', 'Schalensitze, Alcantara', 'BEATS Audio\xa0System mit DAB+', 'Brembo Bremsanlage', 'beheizbare Windschutzscheibe', 'Connectivity Box inkl. Wireless Charger', 'Adaptive Fahrwerksregelung DCC', 'Vodersitze beheizbar', '19\xa0Zoll Leichtmetallräder "Cupra" Diamond', 'El. Heckklappe inkl. virtuelles Pedal', 'Parklenkassistent', 'Toter-Winkel-Assistent und Ausparkassistent', 'An ...
# 2019-06-21 09:18:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-4drive-dsg-gasoline-white-458c1647-1615-4c39-9b6c-9a502755a974>
# {'url': 'https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-4drive-dsg-gasoline-white-458c1647-1615-4c39-9b6c-9a502755a974', 'make_model': 'Cupra Ateca', 'short_description': '2,0 TSI 4Drive DSG', 'body_type': 'Off-Road', 'price': 47990, 'vat': 'VAT deductible', 'km': '10 km', 'registration': None, 'prev_owner': '02/2019', 'kW': None, 'hp': '221 kW', 'Type': ['', 'Used', '', 'Gasoline'], 'Next Inspection': '\n02/2022\n', 'CO2 Emission': ['\n168 g CO2/km (comb)\n'], None: [], 'Make': ['\nCupra\n'], 'Model': ['\n', 'Ateca', '\n'], 'Offer Number': ['\n805-19249\n'], 'First Registration': ['\n', '2019', '\n'], 'Body Color': ['\n', 'White', '\n'], 'Paint Type': ['\nMetallic\n'], 'Body Color Original': ['\nNevada-Weiß Metallic\n'], 'Upholstery': ['\nFull leather\n'], 'Body': ['\n', 'Off-Road', '\n'], 'Nr. of Doors': ['\n5\n'], 'Nr. of Seats': ['\n5\n'], 'Gearing Type': ['\n', 'Automatic', '\n'], 'Gears': ['\n7\n'], 'Displacement': ['\n1,984 cc\n'], 'Weight': ['\n1,632 kg\n'], 'Drive chain': ['\n4WD\n'], 'Fuel': ['\n', 'Gasoline', '\n'], 'Consumption': [['7.4 l/100 km (comb)'], [], []], '\nComfort & Convenience\n': ['Air conditioning', 'Armrest', 'Automatic climate control', 'Cruise control', 'Keyless central door lock', 'Multi-function steering wheel', 'Park Distance Control', 'Parking assist system sensors front', 'Parking assist system sensors rear', 'Power windows', 'Rain sensor', 'Seat heating'], '\nEntertainment & Media\n': ['CD player', 'Hands-free equipment', 'Radio'], '\nExtras\n': ['Roof rack', 'Sport seats', 'Trailer hitch'], '\nSafety & Security\n': ['ABS', 'Central door lock', 'Daytime running lights', 'Driver-side airbag', 'Electronic stability control', 'Isofix', 'Passenger-side airbag', 'Power steering'], 'description': ['\nGepäckraumklappe elektrisch, Ausstelldach, Leichtmetallfelgen 19 Zoll, Sportpaket, Berganfahrhilfe, Lichtsensor, USB Schnittstelle, LED-Rückleuchten, LED-Hauptscheinwerfer, Park Lenkassistent, Reifendruckkontrolle, Außenspiegel beheizbar, Fensterheber elektrisch hinten, Windschutzscheibe beheizbar, Seitenfenster ab B-Säule abgedunkelt, Coming-Home-Funktion\n']}
# 2019-06-21 09:18:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-221kw-4drive-dsg-gasoline-white-faadb833-9a97-4b34-b629-e54d479c59bc>
# {'url': 'https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-221kw-4drive-dsg-gasoline-white-faadb833-9a97-4b34-b629-e54d479c59bc', 'make_model': 'Cupra Ateca', 'short_description': '2.0 TSI 221kW 4Drive DSG', 'body_type': 'Off-Road', 'price': 47890, 'vat': 'VAT deductible', 'km': '- km', 'registration': None, 'prev_owner': '-/-', 'kW': None, 'hp': '221 kW', 'Type': ['', 'New', '', 'Super Plus 98 (Particulate Filter)'], 'Available from': '\n01/10/19\n', 'Warranty': ['\n', '\n', '\n168 g CO2/km (comb)\n'], 'Full Service': ['\n', '\n', '\nEuro 6d-TEMP\n'], 'Non-smoking Vehicle': ['\n', '\n', '\n4 (Green)\n'], None: [], 'Make': ['\nCupra\n'], 'Model': ['\n', 'Ateca', '\n'], 'Body Color': ['\n', 'White', '\n'], 'Paint Type': ['\nMetallic\n'], 'Body Color Original': ['\nNevada Weiß\n'], 'Upholstery': ['\nalcantara, Black\n'], 'Body': ['\n', 'Off-Road', '\n'], 'Nr. of Doors': ['\n4\n'], 'Nr. of Seats': ['\n5\n'], 'Model Code': ['\n7593/AOD\n'], 'Country version': ['\nGermany\n'], 'Gearing Type': ['\n', 'Automatic', '\n'], 'Displacement': ['\n1,984 cc\n'], 'Drive chain': ['\n4WD\n'], 'Fuel': ['\n', 'Super Plus 98 (Particulate Filter)', '\n'], 'Consumption': [['7.4 l/100 km (comb)'], ['8.9 l/100 km (city)'], ['6.5 l/100 km (country)']], 'CO2 Emission': ['\n168 g CO2/km (comb)\n'], 'Emission Class': ['\nEuro 6d-TEMP\n'], '\nComfort & Convenience\n': ['Air conditioning', 'Armrest', 'Automatic climate control', 'Electrical side mirrors', 'Electric tailgate', 'Hill Holder', 'Keyless central door lock', 'Leather steering wheel', 'Light sensor', 'Lumbar support', 'Multi-function steering wheel', 'Navigation system', 'Park Distance Control', 'Parking assist system camera', 'Parking assist system self-steering', 'Parking assist system sensors front', 'Parking assist system sensors rear', 'Power windows', 'Rain sensor', 'Seat heating', 'Start-stop system'], '\nEntertainment & Media\n': ['Bluetooth', 'CD player', 'Digital radio', 'Hands-free equipment', 'On-board computer', 'Radio', 'Sound system', 'USB'], '\nExtras\n': ['Alloy wheels', 'Shift paddles', 'Sport package', 'Sport seats', 'Sport suspension', 'Touch screen', 'Trailer hitch', 'Voice Control'], '\nSafety & Security\n': ['ABS', 'Adaptive Cruise Control', 'Blind spot monitor', 'Central door lock', 'Daytime running lights', 'Driver drowsiness detection', 'Driver-side airbag', 'Electronic stability control', 'Emergency brake assistant', 'Isofix', 'Lane departure warning system', 'LED Daytime Running Lights', 'LED Headlights', 'Passenger-side airbag', 'Power steering', 'Side airbag', 'Tire pressure monitoring system', 'Traction control', 'Traffic sign recognition'], 'description': ['\n', 'Serienausstattung:', '- Fahrer- und Beifahrerairbag', '- Seitenairbag für Fahrer und Beifahrer', '- Kopf- und Knieairbag für Fahrer und Beifahrer', '- ABS', '- ESP', '- ASR', '- Differentialsperre (elektronisch) XDS', '- elektronische Parkbremse', '- elektr. Fensterheber vorne und hinten', '- Bordcomputer', '- Müdigkeitserkennung', '- Reifendruckkontrollsystem', '- SEAT Drive Profile mit Driving Experience-Knopf', '- Umfeldbeobachtungssystem mit Notbremsfunktion', '- Fahrer- und Beifahrersitz höhenverstellbar', '- Fußraumbeleuchtung', '- 2- Zonen Climatronic', '- Außenspiegel elektr. verstell,- beheiz, und Anklappbar', '- Geschwindigkeitsregelanlage', '- Lendenwirbelstütze für Fahrersitz', '- Doppelauspuffrohr', '- abgedunkelte Heck und Seitenscheiben', '- LED-Innenlicht-Paket', '- Innenspiegel automatisch Abblendbar', '- Rückfahrkamera', '- Voll-LED-Scheinwerfer', '- LED-Nebelscheinwerfer', '- Abblend- und Fernlicht in LED', '- dynamische Leuchtweitenregulierung', '- Navigationssystem 8 Zoll mit Radio/CD, 2 USB und 1. AUX-IN Anschluss', '- Connectivity Box', '- Full-Link', '- W-Lan Audio Streaming', '- Virtuelles Cockpit', '- Parklenkassistent mit Parksensoren voren und hinten inkl. Rückfahrkamera', '- Dachreling in Schwarz\xa0', 'uvm', 'Sonderausstattung', '- Businesspaket Cupra beinhaletet: Beats A ...
# 2019-06-21 09:18:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com//offers/cupra-ateca-seat-ateca-2-0-tsi-4drive-dsg-navi-pano-brembo-le-gasoline-black-3d46f8ce-698f-4994-b4ea-62327481c778>
# {'url': 'https://www.autoscout24.com//offers/cupra-ateca-seat-ateca-2-0-tsi-4drive-dsg-navi-pano-brembo-le-gasoline-black-3d46f8ce-698f-4994-b4ea-62327481c778', 'make_model': 'Cupra Ateca', 'short_description': 'SEAT Ateca 2.0 TSI 4Drive DSG Navi PANO Brembo LE', 'body_type': 'Off-Road', 'price': 47980, 'vat': 'VAT deductible', 'km': '3,000 km', 'registration': None, 'prev_owner': '02/2019', 'kW': None, 'hp': '221 kW', 'Type': ['', 'Used', '', 'Super 95 (Particulate Filter)'], 'Previous Owners': '\n1\n', 'Next Inspection': ['\n06/2021\n', '\n168 g CO2/km (comb)\n'], 'Inspection new': ['\nYes\n', '\nEuro 6d-TEMP\n'], 'Warranty': ['\n60 months\n'], 'Full Service': ['\n', '\n'], 'Non-smoking Vehicle': ['\n', '\n'], None: [], 'Make': ['\nCupra\n'], 'Model': ['\n', 'Ateca', '\n'], 'Offer Number': ['\n13368/19/75_4284\n'], 'First Registration': ['\n', '2019', '\n'], 'Body Color': ['\n', 'Black', '\n'], 'Paint Type': ['\nMetallic\n'], 'Body Color Original': ['\nMagic Schwarz Metallic\n'], 'Upholstery': ['\nalcantara, Black\n'], 'Body': ['\n', 'Off-Road', '\n'], 'Nr. of Doors': ['\n5\n'], 'Nr. of Seats': ['\n5\n'], 'Model Code': ['\n7593/AOD\n'], 'Gearing Type': ['\n', 'Automatic', '\n'], 'Gears': ['\n7\n'], 'Displacement': ['\n1,984 cc\n'], 'Cylinders': ['\n4\n'], 'Weight': ['\n1,615 kg\n'], 'Drive chain': ['\n4WD\n'], 'Fuel': ['\n', 'Super 95 (Particulate Filter)', '\n'], 'Consumption': [['7.4 l/100 km (comb)'], ['8.9 l/100 km (city)'], ['6.5 l/100 km (country)']], 'CO2 Emission': ['\n168 g CO2/km (comb)\n'], 'Emission Class': ['\nEuro 6d-TEMP\n'], '\nComfort & Convenience\n': ['Air conditioning', 'Armrest', 'Automatic climate control', 'Cruise control', 'Electrically heated windshield', 'Electrical side mirrors', 'Electric tailgate', 'Hill Holder', 'Keyless central door lock', 'Leather steering wheel', 'Light sensor', 'Lumbar support', 'Multi-function steering wheel', 'Navigation system', 'Panorama roof', 'Park Distance Control', 'Parking assist system camera', 'Parking assist system self-steering', 'Parking assist system sensors front', 'Parking assist system sensors rear', 'Power windows', 'Rain sensor', 'Seat heating', 'Start-stop system', 'Sunroof'], '\nEntertainment & Media\n': ['Bluetooth', 'CD player', 'Digital radio', 'Hands-free equipment', 'Radio', 'Sound system', 'USB'], '\nExtras\n': ['Alloy wheels', 'Roof rack', 'Shift paddles', 'Sport seats', 'Touch screen', 'Trailer hitch', 'Voice Control'], '\nSafety & Security\n': ['ABS', 'Adaptive Cruise Control', 'Blind spot monitor', 'Central door lock', 'Daytime running lights', 'Driver drowsiness detection', 'Driver-side airbag', 'Electronic stability control', 'Emergency brake assistant', 'Immobilizer', 'Isofix', 'Lane departure warning system', 'LED Daytime Running Lights', 'LED Headlights', 'Passenger-side airbag', 'Power steering', 'Side airbag', 'Tire pressure monitoring system', 'Traction control', 'Traffic sign recognition'], 'description': ['\n', ' * Radio-Navigation: Navigationssystem Plus mit 8"" Farb-Touch-Screen - Dynamische Routenführung über TMC - CD/DVD-Player im Handschuhfach - Integr. Festplatte - 2 SD-Kartenslots - USB- und Aux-in-Schnittstelle - 2 USB- Ladebuchsen für die 2. Sitzreihe - Sprachsteuerung - SMS, WLAN Audio-Streaming - Vorinstallierte Navigationsdaten Connectivity Box im Ablagefach der Mittelkonsole inkl. Wireless Charger Full Link - MirrorLink - Android Auto - Apple CarPlay', ' * Navigationsdaten Europa inkl. MAPCARE', ' * Bremsanlage BREMBO 4-Kolben-High-Perform', ' * Sofort lieferbar !', ' * Panorama-Glas-Schiebedach', ' * Paket: Winter', ' * Radiozubehör: BeatsAudio Soundsystem', ' * Räder: Leichtmetallr. (4) CUPRA Diamond', ' * Paket: Fahrassistenz-Paket V', ' * Anhängevorrichtung, schwenkbar', ' * Lackierung: Metallic', ' * Heckklappe elektrisch betätigt', ' * Windschutzscheibe beheizbar', ' * Airbag: Airbag für Fahrer und Beifahrer', ' * Airbag: Seitenairbag für Fahrer und Beif', ' * Airbag: Kopfairbag-System, vorn und hint', ' * Airbag:  ...
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-cupra-2-0tsi-dsg-4drive-pano-v-cockpit-dcc-sitzhzg-gasoline-black-50a77f2f-49d2-4be3-8b70-53ffc4598d65> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-cupra-2-0tsi-dsg-4drive-brembo-pano-dcc-v-cockpit-gasoline-grey-9a3f697b-c029-4f92-9bc2-28b10d215509> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-cupra-2-0tsi-dsg-4drive-brembo-pano-dcc-v-cockpit-gasoline-grey-6ff13b16-9816-40be-9f48-54cb9cf4c66f> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-cupra-2-0tsi-dsg-4drive-pano-v-cockpit-dcc-sitzhzg-gasoline-black-e3f3d47a-2d9f-4993-b7ff-db923f6a8f74> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-4drive-dsg-gasoline-grey-dcb4d905-d86a-4e79-847a-ad85bc46d064>
# {'url': 'https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-4drive-dsg-gasoline-grey-dcb4d905-d86a-4e79-847a-ad85bc46d064', 'make_model': 'Cupra Ateca', 'short_description': '2,0 TSI 4Drive DSG', 'body_type': 'Off-Road', 'price': 47990, 'vat': 'VAT deductible', 'km': '1,700 km', 'registration': None, 'prev_owner': '02/2019', 'kW': None, 'hp': '221 kW', 'Type': ['', 'Used', '', 'Gasoline'], 'Next Inspection': '\n02/2022\n', 'CO2 Emission': ['\n168 g CO2/km (comb)\n'], None: [], 'Make': ['\nCupra\n'], 'Model': ['\n', 'Ateca', '\n'], 'Offer Number': ['\n201-8923\n'], 'First Registration': ['\n', '2019', '\n'], 'Body Color': ['\n', 'Grey', '\n'], 'Paint Type': ['\nMetallic\n'], 'Body Color Original': ['\nGranit-Grau Met.\n'], 'Upholstery': ['\nCloth\n'], 'Body': ['\n', 'Off-Road', '\n'], 'Nr. of Doors': ['\n5\n'], 'Nr. of Seats': ['\n5\n'], 'Gearing Type': ['\n', 'Automatic', '\n'], 'Gears': ['\n7\n'], 'Displacement': ['\n1,984 cc\n'], 'Weight': ['\n1,632 kg\n'], 'Drive chain': ['\n4WD\n'], 'Fuel': ['\n', 'Gasoline', '\n'], 'Consumption': [['7.4 l/100 km (comb)'], [], []], 'description': []}
# 2019-06-21 09:18:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com//offers/cupra-ateca-seat-cupra-ateca-2-0-tsi-4drive-dsg-gasoline-grey-10be11ab-73d1-4d2e-bb50-87daa743ba19>
# {'url': 'https://www.autoscout24.com//offers/cupra-ateca-seat-cupra-ateca-2-0-tsi-4drive-dsg-gasoline-grey-10be11ab-73d1-4d2e-bb50-87daa743ba19', 'make_model': 'Cupra Ateca', 'short_description': 'SEAT Cupra Ateca 2.0 TSI 4Drive DSG', 'body_type': 'Off-Road', 'price': 47890, 'vat': 'VAT deductible', 'km': '5,000 km', 'registration': None, 'prev_owner': '11/2018', 'kW': None, 'hp': '221 kW', 'Type': ['', 'Demonstration', '', 'Super 95 (Particulate Filter)'], 'Availability': '\nin 180 days from ordering\n', 'Previous Owners': ['\n1\n', '\n168 g CO2/km (comb)\n'], 'Next Inspection': ['\n11/2021\n', '\nEuro 6d-TEMP\n'], 'Warranty': ['\n36 months\n'], 'Full Service': ['\n', '\n'], 'Non-smoking Vehicle': ['\n', '\n'], None: [], 'Make': ['\nCupra\n'], 'Model': ['\n', 'Ateca', '\n'], 'Offer Number': ['\n519230_SG_6983\n'], 'First Registration': ['\n', '2018', '\n'], 'Body Color': ['\n', 'Grey', '\n'], 'Paint Type': ['\nMetallic\n'], 'Body Color Original': ['\nRodium Grau Metallic\n'], 'Upholstery': ['\nalcantara, Black\n'], 'Body': ['\n', 'Off-Road', '\n'], 'Nr. of Doors': ['\n5\n'], 'Nr. of Seats': ['\n5\n'], 'Model Code': ['\n7593/AOD\n'], 'Country version': ['\nGermany\n'], 'Gearing Type': ['\n', 'Automatic', '\n'], 'Gears': ['\n7\n'], 'Displacement': ['\n1,984 cc\n'], 'Cylinders': ['\n4\n'], 'Weight': ['\n1,615 kg\n'], 'Drive chain': ['\n4WD\n'], 'Fuel': ['\n', 'Super 95 (Particulate Filter)', '\n'], 'Consumption': [['7.4 l/100 km (comb)'], ['8.9 l/100 km (city)'], ['6.5 l/100 km (country)']], 'CO2 Emission': ['\n168 g CO2/km (comb)\n'], 'Emission Class': ['\nEuro 6d-TEMP\n'], '\nComfort & Convenience\n': ['Air conditioning', 'Armrest', 'Automatic climate control', 'Cruise control', 'Electrical side mirrors', 'Electric tailgate', 'Hill Holder', 'Keyless central door lock', 'Leather steering wheel', 'Light sensor', 'Lumbar support', 'Multi-function steering wheel', 'Navigation system', 'Panorama roof', 'Park Distance Control', 'Parking assist system camera', 'Parking assist system self-steering', 'Parking assist system sensors front', 'Parking assist system sensors rear', 'Power windows', 'Rain sensor', 'Seat heating', 'Start-stop system', 'Sunroof'], '\nEntertainment & Media\n': ['Bluetooth', 'CD player', 'Digital radio', 'Hands-free equipment', 'Radio', 'Sound system', 'USB'], '\nExtras\n': ['Alloy wheels', 'Roof rack', 'Shift paddles', 'Sport package', 'Sport seats', 'Touch screen', 'Voice Control'], '\nSafety & Security\n': ['ABS', 'Adaptive Cruise Control', 'Alarm system', 'Blind spot monitor', 'Central door lock', 'Daytime running lights', 'Driver drowsiness detection', 'Driver-side airbag', 'Electronic stability control', 'Emergency brake assistant', 'Immobilizer', 'Isofix', 'Lane departure warning system', 'LED Daytime Running Lights', 'LED Headlights', 'Passenger-side airbag', 'Power steering', 'Side airbag', 'Tire pressure monitoring system', 'Traction control', 'Traffic sign recognition'], 'description': ['\n', ' * Getriebe: 7-Gang-Doppelkupplungsgetriebe', ' * Climatronic mit el. Temperaturregelung', ' * Ottopartikelfilter', ' * Top View Kamera inkl. Rückfahrkamera', ' * Schlüsselloses Schließ- und Startsystem', ' * Radio-Navigation: Navigationssystem Plus', ' * Panorama-Glas-Schiebedach elektrisch mit Sonnenschutzjalousie', ' * Bremsanlage BREMBO 4-Kolben-High-Performance, vorn', ' * Radiozubehör: BeatsAudio Soundsystem 9 Lautsprecher, digitaler 12-Kanal-Verstärker, Subwoofer, 340 Watt Gesamtleistung', ' * Paket: Winter - Scheinwerfer-Reinigungsanlage - Scheibenwaschdüsen beheizbar - Vordersitze beheizbar', ' * Paket: Fahrassistenz-Paket V - Stauassistent + Notfallassistent - Fernlichtassistent - Spurhalteassistent - Verkehrszeichenerkennung - Automatische Distanzregelung ACC bis 210 km/h - Toter Winkel Assistent und Ausparkassistent', ' * Paket: Black-Paket Interieur - Rahmen der Luftausströmer, der Schaltkulisse und der Türöffner in ""Glossy Black""', ' * Heckklappe elektrisch betätigt Öffnung & Schließung inkl. sens ...
# 2019-06-21 09:18:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com//offers/cupra-ateca-cupra-2-0tsi-dsg-4drive-pano-v-cockpit-dcc-sitzhzg-gasoline-black-2d29a523-a31c-4ca3-8689-d18b45137c3a>
# {'url': 'https://www.autoscout24.com//offers/cupra-ateca-cupra-2-0tsi-dsg-4drive-pano-v-cockpit-dcc-sitzhzg-gasoline-black-2d29a523-a31c-4ca3-8689-d18b45137c3a', 'make_model': 'Cupra Ateca', 'short_description': 'CUPRA 2.0TSI DSG 4DRIVE Pano V-Cockpit DCC Sitzhzg', 'body_type': 'Off-Road', 'price': 47870, 'vat': 'VAT deductible', 'km': '- km', 'registration': None, 'prev_owner': '-/-', 'kW': None, 'hp': '221 kW', 'Type': ['', 'New', '', 'Super 95 (Particulate Filter)'], 'Inspection new': '\nYes\n', 'Warranty': ['\n24 months\n', '\n168 g CO2/km (comb)\n'], 'Full Service': ['\n', '\n', '\nEuro 6\n'], 'Non-smoking Vehicle': ['\n', '\n', '\n4 (Green)\n'], None: [], 'Make': ['\nCupra\n'], 'Model': ['\n', 'Ateca', '\n'], 'Offer Number': ['\n5125061380NW\n'], 'Body Color': ['\n', 'Black', '\n'], 'Paint Type': ['\nMetallic\n'], 'Body Color Original': ['\nmagic schwarz\n'], 'Upholstery': ['\nalcantara, Other\n'], 'Body': ['\n', 'Off-Road', '\n'], 'Nr. of Doors': ['\n5\n'], 'Nr. of Seats': ['\n5\n'], 'Model Code': ['\n7593/AOD\n'], 'Country version': ['\nGermany\n'], 'Gearing Type': ['\n', 'Automatic', '\n'], 'Gears': ['\n7\n'], 'Displacement': ['\n1,984 cc\n'], 'Cylinders': ['\n4\n'], 'Weight': ['\n1,780 kg\n'], 'Drive chain': ['\n4WD\n'], 'Fuel': ['\n', 'Super 95 (Particulate Filter)', '\n'], 'Consumption': [['4.7 l/100 km (comb)'], ['8.9 l/100 km (city)'], ['6.5 l/100 km (country)']], 'CO2 Emission': ['\n168 g CO2/km (comb)\n'], 'Emission Class': ['\nEuro 6\n'], '\nComfort & Convenience\n': ['Air conditioning', 'Armrest', 'Automatic climate control', 'Cruise control', 'Electrically heated windshield', 'Electrical side mirrors', 'Electric tailgate', 'Hill Holder', 'Keyless central door lock', 'Light sensor', 'Lumbar support', 'Multi-function steering wheel', 'Navigation system', 'Panorama roof', 'Park Distance Control', 'Parking assist system camera', 'Parking assist system self-steering', 'Parking assist system sensors front', 'Parking assist system sensors rear', 'Power windows', 'Rain sensor', 'Seat heating', 'Start-stop system', 'Sunroof'], '\nEntertainment & Media\n': ['Bluetooth', 'CD player', 'Digital radio', 'Hands-free equipment', 'On-board computer', 'Radio', 'Sound system'], '\nExtras\n': ['Alloy wheels', 'Roof rack', 'Shift paddles', 'Sport seats', 'Sport suspension', 'Voice Control'], '\nSafety & Security\n': ['ABS', 'Adaptive Cruise Control', 'Blind spot monitor', 'Central door lock', 'Daytime running lights', 'Driver drowsiness detection', 'Driver-side airbag', 'Electronic stability control', 'Emergency brake assistant', 'Immobilizer', 'Isofix', 'Lane departure warning system', 'LED Daytime Running Lights', 'LED Headlights', 'Passenger-side airbag', 'Power steering', 'Side airbag', 'Tire pressure monitoring system', 'Traction control', 'Traffic sign recognition', 'Xenon headlights'], 'description': ['\n', 'Getriebe:', ' Automatik', 'Technik:', ' Allrad, Bordcomputer, Sperrdifferential, Adaptives Daempfungssystem, Partikelfilter, Start-Stop-Automatik, Schaltwippen, Volldigitales Kombiinstrument', 'Assistenten:', ' Totwinkel-Assistent, Müdigkeitserkennung, Verkehrszeichenerkennung, Park-Lenk-Assistent, Regensensor, Fernlichtassistent, Lichtsensor, Notbremsassistent, Berganfahrassistent, Spurhalteassistent, Spurwechselassistent, Abstandsregeltempomat', 'Komfort:', ' Servolenkung, Zentralverriegelung, Elektrischer Fensterheber, Sitzheizung, Elektrische Aussenspiegel, Teilbare Ruecksitzlehne, Tempomat, Multifunktionslenkrad, Keyless Go Startfunktion, Innenspiegel autom. abblendbar, Mittelarmlehne, Sportsitze, ParkDistanceControl vorne und hinten, Elektrische Heckklappe, Beheizbare Frontscheibe, Keyless Entry, Ambiente Beleuchtung, Lordosenstütze, Geschwindigkeitsbegrenzungsanlage, Klimaautomatik-2-Zonen', 'Sicht:', ' LED-Hauptscheinwerfer, Blendfreies Fernlicht, LED-Tagfahrlicht, 360 Grad Kamera, LED-Rueckleuchten, Scheinwerferregulierung, Colorverglasung, Scheinwerferreinigung, Aussenspiegel beheizbar, Privacyverglasung', ' ...
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-cupra-2-0tsi-dsg-4drive-pano-brembo-dcc-v-cockpit-gasoline-black-47857cf8-be6c-4bed-8fb1-01f4b438230d> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-cupra-2-0tsi-dsg-4drive-pano-brembo-dcc-v-cockpit-gasoline-black-e784db7d-267c-4b6e-a6c0-ebacf2743bda> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-4-drive-dsg-ahk-fracht-gasoline-grey-cf0b1cc8-a5b8-4621-9b45-acc9673437c3> (referer: https://www.autoscout24.com/lst/cupra/ateca?sort=price&desc=0&ustate=N%2CU&size=20&page=11&atype=C&)
# 2019-06-21 09:18:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com//offers/cupra-ateca-cupra-2-0tsi-dsg-4drive-pano-v-cockpit-dcc-sitzhzg-gasoline-black-50a77f2f-49d2-4be3-8b70-53ffc4598d65>
# ...
# 2019-06-21 09:18:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com//offers/cupra-ateca-2-0tsi-4drive-brembo-schiebedach-beats-winter-pake-gasoline-black-eae556b8-4531-4f7e-8e61-13b82b542255>
# {'url': 'https://www.autoscout24.com//offers/cupra-ateca-2-0tsi-4drive-brembo-schiebedach-beats-winter-pake-gasoline-black-eae556b8-4531-4f7e-8e61-13b82b542255', 'make_model': 'Cupra Ateca', 'short_description': '2.0TSI 4Drive Brembo Schiebedach Beats Winter-Pake', 'body_type': 'Off-Road', 'price': 47480, 'vat': 'VAT deductible', 'km': '10 km', 'registration': None, 'prev_owner': '-/-', 'kW': None, 'hp': '221 kW', 'Type': ['', 'New', '', 'Super Plus 98'], 'Warranty': '\n24 months\n', 'Full Service': ['\n', '\n', '\n168 g CO2/km (comb)\n'], 'Non-smoking Vehicle': ['\n', '\n', '\nEuro 6d-TEMP\n'], 'Emission Label': ['\n4 (Green)\n'], None: [], 'Make': ['\nCupra\n'], 'Model': ['\n', 'Ateca', '\n'], 'Offer Number': ['\n6536282\n'], 'Body Color': ['\n', 'Black', '\n'], 'Paint Type': ['\nMetallic\n'], 'Body Color Original': ['\nmagic schwarz\n'], 'Upholstery': ['\nalcantara, Black\n'], 'Body': ['\n', 'Off-Road', '\n'], 'Nr. of Doors': ['\n5\n'], 'Nr. of Seats': ['\n5\n'], 'Model Code': ['\n7593/AOD\n'], 'Country version': ['\nGermany\n'], 'Gearing Type': ['\n', 'Automatic', '\n'], 'Gears': ['\n7\n'], 'Displacement': ['\n1,984 cc\n'], 'Cylinders': ['\n4\n'], 'Weight': ['\n1,615 kg\n'], 'Drive chain': ['\n4WD\n'], 'Fuel': ['\n', 'Super Plus 98', '\n'], 'Consumption': [['7.4 l/100 km (comb)'], ['8.9 l/100 km (city)'], ['6.5 l/100 km (country)']], 'CO2 Emission': ['\n168 g CO2/km (comb)\n'], 'Emission Class': ['\nEuro 6d-TEMP\n'], '\nComfort & Convenience\n': ['Air conditioning', 'Armrest', 'Automatic climate control', 'Cruise control', 'Electrical side mirrors', 'Electric tailgate', 'Hill Holder', 'Keyless central door lock', 'Leather steering wheel', 'Light sensor', 'Lumbar support', 'Multi-function steering wheel', 'Navigation system', 'Panorama roof', 'Park Distance Control', 'Parking assist system camera', 'Parking assist system self-steering', 'Parking assist system sensors front', 'Parking assist system sensors rear', 'Power windows', 'Rain sensor', 'Seat heating', 'Start-stop system', 'Sunroof'], '\nEntertainment & Media\n': ['Bluetooth', 'CD player', 'Digital radio', 'Hands-free equipment', 'MP3', 'On-board computer', 'Radio', 'Sound system'], '\nExtras\n': ['Alloy wheels', 'Roof rack', 'Shift paddles', 'Sport package', 'Sport seats', 'Sport suspension', 'Touch screen', 'Voice Control'], '\nSafety & Security\n': ['ABS', 'Adaptive Cruise Control', 'Blind spot monitor', 'Central door lock', 'Daytime running lights', 'Driver drowsiness detection', 'Driver-side airbag', 'Electronic stability control', 'Emergency brake assistant', 'Immobilizer', 'Isofix', 'Lane departure warning system', 'LED Daytime Running Lights', 'LED Headlights', 'Passenger-side airbag', 'Power steering', 'Side airbag', 'Tire pressure monitoring system', 'Traction control', 'Traffic sign recognition', 'Xenon headlights'], 'description': ['\n', 'Getriebe', 'Automatik', 'Technik', 'Allrad', 'Bordcomputer', 'Sperrdifferential', 'Adaptives Daempfungssystem', 'Start-Stop-Automatik', 'Sportabgasanlage', 'Schaltwippen', 'Volldigitales Kombiinstrument', 'Assistenten', 'Totwinkel-Assistent', 'Müdigkeitserkennung', 'Verkehrszeichenerkennung', 'Park-Lenk-Assistent', 'Regensensor', 'Fernlichtassistent', 'Lichtsensor', 'Notbremsassistent', 'Berganfahrassistent', 'Spurhalteassistent', 'Spurwechselassistent', 'Abstandsregeltempomat', 'Ausparkassistent', 'Kollisionswarner', 'Komfort', 'Servolenkung', 'Zentralverriegelung', 'Elektrischer Fensterheber', 'Sitzheizung', 'Elektrische Aussenspiegel', 'Teilbare Ruecksitzlehne', 'Tempomat', 'Multifunktionslenkrad', 'Keyless Go Startfunktion', 'Innenspiegel autom. abblendbar', 'Mittelarmlehne', 'Innenraumfilter', 'Lenksaeule einstellbar', 'Sportsitze', 'ParkDistanceControl vorne und hinten', 'Elektrische Heckklappe', 'Keyless Entry', 'Ambiente Beleuchtung', 'Lordosenstütze', 'Lederlenkrad', 'Klimaautomatik-2-Zonen', 'Sicht', 'LED-Hauptscheinwerfer', 'LED-Tagfahrlicht', '360 Grad Kamera', 'LED-Rueckleuchten', 'Scheinwerferregulierung',  ...
# 2019-06-21 09:18:17 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=131&atype=C&> (referer: None)
# 2019-06-21 09:18:17 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=141&atype=C&> (referer: None)
# 2019-06-21 09:18:17 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=111&atype=C&> (referer: None)
# 2019-06-21 09:18:17 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=101&atype=C&> (referer: None)
# 2019-06-21 09:18:17 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=71&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:17 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=81&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:17 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=61&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:17 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=91&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:17 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=121&atype=C&> (referer: None)
# 2019-06-21 09:18:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-dsg-4drive-led-navigation-brembo-panorama-gasoline-grey-72de2d22-04d8-43ba-bdab-0517872a9cdc>
# {'url': 'https://www.autoscout24.com//offers/cupra-ateca-2-0-tsi-dsg-4drive-led-navigation-brembo-panorama-gasoline-grey-72de2d22-04d8-43ba-bdab-0517872a9cdc', 'make_model': 'Cupra Ateca', 'short_description': '2.0 TSI DSG 4Drive LED/Navigation/BREMBO/Panorama/', 'body_type': 'Off-Road', 'price': 47490, 'vat': 'VAT deductible', 'km': '8,999 km', 'registration': None, 'prev_owner': '01/2019', 'kW': None, 'hp': '221 kW', 'Type': ['', 'Demonstration', '', 'Regular/Benzine 91'], 'Previous Owners': '\n1\n', 'Next Inspection': ['\n01/2022\n', '\n168 g CO2/km (comb)\n'], 'Warranty': ['\n', '\n', '\nEuro 6d-TEMP\n'], 'Full Service': ['\n', '\n', '\n4 (Green)\n'], 'Non-smoking Vehicle': ['\n', '\n'], None: [], 'Make': ['\nCupra\n'], 'Model': ['\n', 'Ateca', '\n'], 'Offer Number': ['\n3PAA2PRRV5\n'], 'First Registration': ['\n', '2019', '\n'], 'Body Color': ['\n', 'Grey', '\n'], 'Paint Type': ['\nMetallic\n'], 'Body Color Original': ['\nRodium Grau Metallic\n'], 'Upholstery': ['\nalcantara, Black\n'], 'Body': ['\n', 'Off-Road', '\n'], 'Nr. of Doors': ['\n5\n'], 'Nr. of Seats': ['\n5\n'], 'Model Code': ['\n7593/AOD\n'], 'Country version': ['\nGermany\n'], 'Gearing Type': ['\n', 'Automatic', '\n'], 'Gears': ['\n7\n'], 'Displacement': ['\n1,984 cc\n'], 'Cylinders': ['\n4\n'], 'Weight': ['\n1,615 kg\n'], 'Drive chain': ['\n4WD\n'], 'Fuel': ['\n', 'Regular/Benzine 91', '\n'], 'Consumption': [['7.4 l/100 km (comb)'], ['8.9 l/100 km (city)'], ['6.5 l/100 km (country)']], 'CO2 Emission': ['\n168 g CO2/km (comb)\n'], 'Emission Class': ['\nEuro 6d-TEMP\n'], '\nComfort & Convenience\n': ['Air conditioning', 'Armrest', 'Automatic climate control', 'Cruise control', 'Electrical side mirrors', 'Electric tailgate', 'Hill Holder', 'Keyless central door lock', 'Leather steering wheel', 'Light sensor', 'Lumbar support', 'Multi-function steering wheel', 'Navigation system', 'Panorama roof', 'Park Distance Control', 'Parking assist system camera', 'Parking assist system self-steering', 'Parking assist system sensors front', 'Parking assist system sensors rear', 'Power windows', 'Rain sensor', 'Seat heating', 'Start-stop system', 'Sunroof', 'Windshield'], '\nEntertainment & Media\n': ['Bluetooth', 'CD player', 'Digital radio', 'Hands-free equipment', 'MP3', 'On-board computer', 'Radio', 'Sound system', 'USB'], '\nExtras\n': ['Alloy wheels', 'Catalytic Converter', 'Roof rack', 'Shift paddles', 'Ski bag', 'Sport package', 'Sport seats', 'Sport suspension', 'Touch screen', 'Voice Control'], '\nSafety & Security\n': ['ABS', 'Adaptive Cruise Control', 'Adaptive headlights', 'Alarm system', 'Blind spot monitor', 'Central door lock', 'Daytime running lights', 'Driver drowsiness detection', 'Driver-side airbag', 'Electronic stability control', 'Emergency brake assistant', 'Immobilizer', 'Isofix', 'Lane departure warning system', 'LED Daytime Running Lights', 'LED Headlights', 'Passenger-side airbag', 'Power steering', 'Side airbag', 'Tire pressure monitoring system', 'Traction control', 'Traffic sign recognition'], 'description': ['\n', 'Technik & Sicherheit:', '18" Reserverad als Notrad, Notfallwerkzeug, Wagenheber', '7-Gang-Automatikgetriebe für Allrad', 'Airbag für Fahrer und Beifahrer mit Knieairbag u.Beifahrer-Airbag- Deaktivierung', 'Außenspiegel, elektrisch anklappbar, elektrisch einstellbar,separat beheizbar', 'Climatronic mit Stauluftregelung, FCKW-frei', 'Diebstahlalarmanlage, Innenraumüber- wachung,Back-up-Horn und Abschleppschutz', 'Diebstahlwarnanlage', 'Dynamiklenkung', 'Elektrische Heckklappe mit virtuellem Pedal (inkl. Kessy mit SAFE)', 'Fensterheber mit Komfortschaltung und Abschaltsicherung, elektrisch', 'Multimedia:', '"BEATS": Sound System der Marke BEATS', 'DAB ("Digital Audio Broadcasting")', 'Digitaler Radioempfang', 'Extern, Aux-In, USB Typ-A, 2x USB Buchseund Ladebuchse(n)', 'Komfort telefonie', 'Mirror Link plus Wireless RSE "App"', 'Navigationsgerät-High', 'Radio High (Gen2)', 'Soundsystem mit Subwoofer "branded" Ausführung 2', 'Sprachste ...
# 2019-06-21 09:18:17 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=131&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:17 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=111&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:17 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=141&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:17 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=101&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:17 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=151&atype=C&> (referer: None)
# 2019-06-21 09:18:17 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=161&atype=C&> (referer: None)
# 2019-06-21 09:18:17 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=121&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:17 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=181&atype=C&> (referer: None)
# 2019-06-21 09:18:17 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=201&atype=C&> (referer: None)
# 2019-06-21 09:18:17 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=171&atype=C&> (referer: None)
# 2019-06-21 09:18:17 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=151&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:17 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=161&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:17 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=191&atype=C&> (referer: None)
# 2019-06-21 09:18:17 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=181&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:17 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=201&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:17 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=171&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:17 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.autoscout24.com/lst/cupra/other?sort=price&desc=0&ustate=N%2CU&size=20&page=191&atype=C&>: HTTP status code is not handled or not allowed
# 2019-06-21 09:18:17 [scrapy.core.engine] INFO: Closing spider (finished)
# 2019-06-21 09:18:17 [scrapy.extensions.feedexport] INFO: Stored jsonlines feed (20 items) in: scout_mmwd.json
# 2019-06-21 09:18:17 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 22883,
#  'downloader/request_count': 60,
#  'downloader/request_method_count/GET': 60,
#  'downloader/response_bytes': 7067261,
#  'downloader/response_count': 60,
#  'downloader/response_status_count/200': 21,
#  'downloader/response_status_count/301': 19,
#  'downloader/response_status_count/404': 20,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2019, 6, 21, 7, 18, 17, 635130),
#  'httperror/response_ignored_count': 39,
#  'httperror/response_ignored_status_count/301': 19,
#  'httperror/response_ignored_status_count/404': 20,
#  'item_scraped_count': 20,
#  'log_count/DEBUG': 80,
#  'log_count/INFO': 49,
#  'request_depth_max': 1,
#  'response_received_count': 60,
#  'scheduler/dequeued': 60,
#  'scheduler/dequeued/memory': 60,
#  'scheduler/enqueued': 60,
#  'scheduler/enqueued/memory': 60,
#  'start_time': datetime.datetime(2019, 6, 21, 7, 18, 14, 634281)}
# 2019-06-21 09:18:17 [scrapy.core.engine] INFO: Spider closed (finished)
